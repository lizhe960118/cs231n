# %% [markdown]
# # Image captions with RNNs

# %%
import time,os,json
import numpy as np
import matplotlib.pyplot as plt

from cs231n.gradient_check import eval_numerical_gradient, eval_numerical_gradient_array
from cs231n.layer_rnn import *
from cs231n.captioning_solver import CaptioningSolver
from cs231n.classifiers.rnn import CaptioningRNN
from cs231n.coco_utils import load_coco_data, sample_coco_minibatch, decode_captions
from cs231n.image_utils import image_from_url

# %matplotlib inline
plt.rcParams['figure.figsize'] = (8.0, 12.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
  """ returns relative error """
  return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))
# Out:
# /home/lizhe/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
data = load_coco_data(pca_features=True)

for k,v in data.items():
    if type(v) == np.ndarray:
        print(k, type(v), v.shape, v.dtype)
    else:
        print(k, type(v), len(v))
# Out:
# train_captions <class 'numpy.ndarray'> (400135, 17) int32
# train_image_idxs <class 'numpy.ndarray'> (400135,) int32
# val_captions <class 'numpy.ndarray'> (195954, 17) int32
# val_image_idxs <class 'numpy.ndarray'> (195954,) int32
# train_features <class 'numpy.ndarray'> (82783, 512) float32
# val_features <class 'numpy.ndarray'> (40504, 512) float32
# idx_to_word <class 'list'> 1004
# word_to_idx <class 'dict'> 1004
# train_urls <class 'numpy.ndarray'> (82783,) <U63
# val_urls <class 'numpy.ndarray'> (40504,) <U63

# %% [markdown]
# ## look at data

# %%
batch_size = 3
captions, features, urls = sample_coco_minibatch(data, batch_size=batch_size)

for i, (caption, url) in enumerate(zip(captions, urls)):
    plt.imshow(image_from_url(url))
    plt.axis('off')
    
    caption_str = decode_captions(caption, data['idx_to_word'])
    plt.title(caption_str)
    plt.show()

# %% [markdown]
# ## Vanilla RNN:step forward

# %%
N, D, H = 3, 10, 4

x = np.linspace(-0.4, 0.7, num=N*D).reshape(N, D)
prev_h = np.linspace(-0.2, 0.5, num=N*H).reshape(N, H)
Wx = np.linspace(-0.1, 0.9, num=D*H).reshape(D, H)
Wh = np.linspace(-0.3, 0.7, num=H*H).reshape(H, H)
b = np.linspace(-0.2, 0.4, num=H)

next_h , _ = rnn_step_forward(x, prev_h, Wx, Wh, b)

expected_next_h = np.asarray([
  [-0.58172089, -0.50182032, -0.41232771, -0.31410098],
  [ 0.66854692,  0.79562378,  0.87755553,  0.92795967],
  [ 0.97934501,  0.99144213,  0.99646691,  0.99854353]])

print('Testing the rnn_step_forward function')
print('the relative error is: %e'% rel_error(next_h, expected_next_h))
# Out:
# Testing the rnn_step_forward function
# the relative error is: 6.292421e-09

# %% [markdown]
# ## Vanilla RNN:step backward

# %%
N, D, H = 4, 5, 6
x = np.random.randn(N, D)
h = np.random.randn(N, H)
Wx = np.random.randn(D, H)
Wh = np.random.randn(H, H)
b = np.random.randn(H)

out, cache = rnn_step_forward(x, h, Wx, Wh, b)

dnext_h = np.random.randn(*out.shape)

fx = lambda x: rnn_step_forward(x, h, Wx, Wh, b)[0]
fh = lambda prev_h: rnn_step_forward(x, h, Wx, Wh, b)[0]
fWx = lambda Wx: rnn_step_forward(x, h, Wx, Wh, b)[0]
fWh = lambda Wh: rnn_step_forward(x, h, Wx, Wh, b)[0]
fb = lambda b: rnn_step_forward(x, h, Wx, Wh, b)[0]

dx_num = eval_numerical_gradient_array(fx, x, dnext_h)
dprev_h_num = eval_numerical_gradient_array(fh, h, dnext_h)
dWx_num = eval_numerical_gradient_array(fWx, Wx, dnext_h)
dWh_num = eval_numerical_gradient_array(fWh, Wh, dnext_h)
db_num = eval_numerical_gradient_array(fb, b, dnext_h)

dx, dprev_h, dWx, dWh, db = rnn_step_backward(dnext_h, cache)

print('Testing rnn_step_backward function')
print('the relative error in dx is: %e'% rel_error(dx, dx_num))
print('the relative error in dprev_h is: %e'% rel_error(dprev_h, dprev_h_num))
print('the relative error in dWx is: %e'% rel_error(dWx, dWx_num))
print('the relative error in dWh is: %e'% rel_error(dWh, dWh_num))
print('the relative error in db is: %e'% rel_error(db, db_num))
# Out:
# Testing rnn_step_backward function
# the relative error in dx is: 1.146791e-09
# the relative error in dprev_h is: 1.127826e-10
# the relative error in dWx is: 2.930531e-09
# the relative error in dWh is: 1.085689e-10
# the relative error in db is: 6.597475e-11

# %% [markdown]
# ## vanilla RNN:forward

# %%
N, T, D, H = 2, 3, 4, 5

x = np.linspace(-0.1, 0.3, num=N*T*D).reshape(N, T, D)
h0 = np.linspace(-0.3, 0.1, num=N*H).reshape(N, H)
Wx = np.linspace(-0.2, 0.4, num=D*H).reshape(D, H)
Wh = np.linspace(-0.4, 0.1, num=H*H).reshape(H, H)
b = np.linspace(-0.7, 0.1, num=H)

h, _ = rnn_forward(x, h0, Wx, Wh, b)
print(h.shape)
expected_h = np.asarray([
  [
    [-0.42070749, -0.27279261, -0.11074945,  0.05740409,  0.22236251],
    [-0.39525808, -0.22554661, -0.0409454,   0.14649412,  0.32397316],
    [-0.42305111, -0.24223728, -0.04287027,  0.15997045,  0.35014525],
  ],
  [
    [-0.55857474, -0.39065825, -0.19198182,  0.02378408,  0.23735671],
    [-0.27150199, -0.07088804,  0.13562939,  0.33099728,  0.50158768],
    [-0.51014825, -0.30524429, -0.06755202,  0.17806392,  0.40333043]]])

print('Testing the rnn_forward function')
print('the relative error is: %e'% rel_error(h, expected_h))
# Out:
# (2, 3, 5)
# Testing the rnn_forward function
# the relative error is: 7.728466e-08

# %% [markdown]
# ## vanilla RNN:backward

# %%
N, D, T, H = 2, 3, 10, 5
x = np.random.randn(N, T, D)
h0 = np.random.randn(N, H)
Wx = np.random.randn(D, H)
Wh = np.random.randn(H, H)
b = np.random.randn(H)

out, cache = rnn_forward(x, h0, Wx, Wh, b)

dout = np.random.randn(*out.shape)

fx = lambda x: rnn_forward(x, h0, Wx, Wh, b)[0]
fh0 = lambda h0: rnn_forward(x, h0, Wx, Wh, b)[0]
fWx = lambda Wx: rnn_forward(x, h0, Wx, Wh, b)[0]
fWh = lambda Wh: rnn_forward(x, h0, Wx, Wh, b)[0]
fb = lambda b: rnn_forward(x, h0, Wx, Wh, b)[0]

dx_num = eval_numerical_gradient_array(fx, x, dout)
dh0_num = eval_numerical_gradient_array(fh0, h0, dout)
dWx_num = eval_numerical_gradient_array(fWx, Wx, dout)
dWh_num = eval_numerical_gradient_array(fWh, Wh, dout)
db_num = eval_numerical_gradient_array(fb, b, dout)

dx, dh0, dWx, dWh, db = rnn_backward(dout, cache)

print('Testing rnn_step_backward function')
print('the relative error in dx is: %e'% rel_error(dx, dx_num))
print('the relative error in dh0 is: %e'% rel_error(dh0, dh0_num))
print('the relative error in dWx is: %e'% rel_error(dWx, dWx_num))
print('the relative error in dWh is: %e'% rel_error(dWh, dWh_num))
print('the relative error in db is: %e'% rel_error(db, db_num))
# Out:
# Testing rnn_step_backward function
# the relative error in dx is: 1.896004e-08
# the relative error in dh0 is: 5.369059e-10
# the relative error in dWx is: 5.248181e-09
# the relative error in dWh is: 3.538220e-10
# the relative error in db is: 4.287874e-10

# %% [markdown]
# ## Word embedding:forward

# %%
N, T, V, D = 2, 4, 5, 3

x = np.asarray([[0, 3, 1, 2], [2, 1, 0, 3]])
W = np.linspace(0, 1, num=V*D).reshape(V, D)

out, _ = word_embedding_forward(x, W)
expected_out = np.asarray([
 [[ 0.,          0.07142857,  0.14285714],
  [ 0.64285714,  0.71428571,  0.78571429],
  [ 0.21428571,  0.28571429,  0.35714286],
  [ 0.42857143,  0.5,         0.57142857]],
 [[ 0.42857143,  0.5,         0.57142857],
  [ 0.21428571,  0.28571429,  0.35714286],
  [ 0.,          0.07142857,  0.14285714],
  [ 0.64285714,  0.71428571,  0.78571429]]])

print('Testing the word_embedding_forward function')
print('the relative error is: %e'% rel_error(out, expected_out))
# Out:
# Testing the word_embedding_forward function
# the relative error is: 1.000000e-08

# %% [markdown]
# ## Word embedding:backward

# %%
N, T, V, D = 50, 3, 5, 6

x = np.random.randint(V, size=(N, T))
W = np.random.randn(V, D)

out, cache = word_embedding_forward(x, W)
dout = np.random.randn(*out.shape)
dW = word_embedding_backward(dout, cache)

f = lambda W: word_embedding_forward(x, W)[0]
dW_num = eval_numerical_gradient_array(f, W, dout)

print('Testing the word_embedding_backward function')
print('the relative error is: %e'% rel_error(dW, dW_num))
# Out:
# Testing the word_embedding_backward function
# the relative error is: 3.275656e-12

# %% [markdown]
# ## temporal affine layer

# %%
N, T, D, M = 2, 3, 4, 5

x = np.random.randn(N, T, D)
w = np.random.randn(D, M)
b = np.random.randn(M)

out, cache = temporal_affine_forward(x, w, b)

dout = np.random.randn(*out.shape)

fx = lambda x: temporal_affine_forward(x, w, b)[0]
fw = lambda w: temporal_affine_forward(x, w, b)[0]
fb = lambda b: temporal_affine_forward(x, w, b)[0]

dx_num = eval_numerical_gradient_array(fx, x, dout)
dw_num = eval_numerical_gradient_array(fw, w, dout)
db_num = eval_numerical_gradient_array(fb, b, dout)

dx, dw, db = temporal_affine_backward(dout, cache)
print('Testing temporal affine layer function')
print('the relative error in dx is: %e'% rel_error(dx, dx_num))
print('the relative error in dw is: %e'% rel_error(dw, dw_num))
print('the relative error in db is: %e'% rel_error(db, db_num))
# Out:
# Testing temporal affine layer function
# the relative error in dx is: 1.076095e-10
# the relative error in dw is: 1.113644e-10
# the relative error in db is: 8.661271e-12

# %% [markdown]
# ## temporal softmax loss

# %%
N, T, V = 100, 1, 10

def check_loss(N, T, V, p):
    x = 0.001 * np.random.randn(N, T, V)
    y = np.random.randint(V, size=(N, T))
    mask = np.random.rand(N, T) <= p
    print(temporal_softmax_loss(x, y, mask)[0])
    
    
check_loss(100, 1, 10, 1.0)   # Should be about 2.3
check_loss(100, 10, 10, 1.0)  # Should be about 23
check_loss(5000, 10, 10, 0.1) # Should be about 2.3

# Gradient check for temporal softmax loss
N, T, V = 7, 8, 9

x = np.random.randn(N, T, V)
y = np.random.randint(V, size=(N, T))
mask = (np.random.rand(N, T) > 0.5)

loss, dx = temporal_softmax_loss(x, y, mask, verbose=False)

dx_num = eval_numerical_gradient(lambda x: temporal_softmax_loss(x, y, mask)[0], x, verbose=False)

print('dx error: ', rel_error(dx, dx_num))
# Out:
# 2.302424964508384
# 23.025533017968918
# 2.332028776422675
# dx error:  3.114479564757834e-08

# %% [markdown]
# ## RNN for image captioning

# %%
N, D, W, H = 10, 20, 30, 40
word_to_idx = {'<NULL>':0, 'cat':2,'dog':3}
V = len(word_to_idx)
T = 13

model = CaptioningRNN(word_to_idx,
                     input_dim=D,
                     wordvec_dim=W,
                     hidden_dim=H,
                     cell_type='rnn',
                     dtype=np.float64)

for k,v in model.params.items():
    model.params[k] = np.linspace(-1.4, 1.3, num=v.size).reshape(*v.shape)
    
features = np.linspace(-1.5, 0.3, num=(N *D)).reshape(N, D)
captions = (np.arange(N * T) % V).reshape(N, T)

loss, grads = model.loss(features, captions)
expected_loss = 9.83235591003

print('loss', loss)
print('expected loss:', expected_loss)
print('the relative error in loss is', rel_error(loss, expected_loss))
# Out:
# loss 9.832355910027387
# expected loss: 9.83235591003
# the relative error in loss is 1.3287867804360955e-13

# %% [markdown]
# ## check captioningRNN class

# %%
batch_size = 2
timesteps = 3
input_dim = 4
wordvec_dim = 5
hidden_dim = 6
word_to_idx = {'<NULL>': 0, 'cat': 2, 'dog': 3}
vocab_size = len(word_to_idx)

captions = np.random.randint(vocab_size, size=(batch_size, timesteps))
features = np.random.randn(batch_size, input_dim)

model = CaptioningRNN(word_to_idx,
          input_dim=input_dim,
          wordvec_dim=wordvec_dim,
          hidden_dim=hidden_dim,
          cell_type='rnn',
          dtype=np.float64,
        )

loss, grads = model.loss(features, captions)

for param_name in sorted(grads):
    f = lambda _: model.loss(features, captions)[0]
    param_grad_num = eval_numerical_gradient(f, model.params[param_name], verbose=False, h=1e-6)
    e = rel_error(param_grad_num, grads[param_name])
    print('%s relative error: %e' % (param_name, e))
# Out:
# W_embed relative error: 2.928338e-09
# W_proj relative error: 1.259895e-08
# W_vocab relative error: 1.476816e-09
# Wh relative error: 1.290441e-08
# Wx relative error: 1.116190e-06
# b relative error: 4.900328e-10
# b_proj relative error: 3.407989e-09
# b_vocab relative error: 1.251453e-10

# %% [markdown]
# ## overfit small data

# %%
small_data = load_coco_data(max_train=100)

small_rnn_model = CaptioningRNN(cell_type='rnn',
                                word_to_idx=data['word_to_idx'],
                                input_dim=data['train_features'].shape[1],
                                hidden_dim=512, 
                                wordvec_dim=256)

small_rnn_solver = CaptioningSolver(small_rnn_model,
                                    small_data,
                                    update_rule='Adam',
                                    num_epochs=50,
                                    batch_size=25,
                                    optim_param={
                                        'learning_rate':5e-3,
                                    },
                                    lr_decay=0.95,
                                    verbose=True,
                                    p_num=10
                                   )

small_rnn_solver.train()

plt.plot(small_rnn_solver.loss_history)
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.title('Training loss history')
plt.show()
# Out:
# (Iteration 1 / 200) loss:  76.728925
# (Epoch 0 / 50), train acc: 0.143588, val_acc: 0.114529)
# (Epoch 1 / 50), train acc: 0.131471, val_acc: 0.091941)
# (Epoch 2 / 50), train acc: 0.188529, val_acc: 0.116353)
# (Iteration 11 / 200) loss:  50.170238
# (Epoch 3 / 50), train acc: 0.226235, val_acc: 0.146176)
# (Epoch 4 / 50), train acc: 0.228706, val_acc: 0.125647)
# (Epoch 5 / 50), train acc: 0.267176, val_acc: 0.161529)
# (Iteration 21 / 200) loss:  37.468306
# (Epoch 6 / 50), train acc: 0.282176, val_acc: 0.161765)
# (Epoch 7 / 50), train acc: 0.299882, val_acc: 0.160412)
# (Iteration 31 / 200) loss:  30.858741
# (Epoch 8 / 50), train acc: 0.325353, val_acc: 0.160647)
# (Epoch 9 / 50), train acc: 0.335353, val_acc: 0.162882)
# (Epoch 10 / 50), train acc: 0.362059, val_acc: 0.154647)
# (Iteration 41 / 200) loss:  25.634407
# (Epoch 11 / 50), train acc: 0.382824, val_acc: 0.157529)
# (Epoch 12 / 50), train acc: 0.398529, val_acc: 0.160471)
# (Iteration 51 / 200) loss:  18.869489
# (Epoch 13 / 50), train acc: 0.402118, val_acc: 0.150706)
# (Epoch 14 / 50), train acc: 0.439235, val_acc: 0.155412)
# (Epoch 15 / 50), train acc: 0.476706, val_acc: 0.157353)
# (Iteration 61 / 200) loss:  13.330110
# (Epoch 16 / 50), train acc: 0.494471, val_acc: 0.153353)
# (Epoch 17 / 50), train acc: 0.534706, val_acc: 0.142353)
# (Iteration 71 / 200) loss:  7.516334
# (Epoch 18 / 50), train acc: 0.548000, val_acc: 0.147471)
# (Epoch 19 / 50), train acc: 0.576882, val_acc: 0.145588)
# (Epoch 20 / 50), train acc: 0.593353, val_acc: 0.140471)
# (Iteration 81 / 200) loss:  5.375513
# (Epoch 21 / 50), train acc: 0.611353, val_acc: 0.147294)
# (Epoch 22 / 50), train acc: 0.652882, val_acc: 0.137412)
# (Iteration 91 / 200) loss:  3.221102
# (Epoch 23 / 50), train acc: 0.662000, val_acc: 0.151176)
# (Epoch 24 / 50), train acc: 0.673235, val_acc: 0.136059)
# (Epoch 25 / 50), train acc: 0.681765, val_acc: 0.143471)
# (Iteration 101 / 200) loss:  2.347648
# (Epoch 26 / 50), train acc: 0.697882, val_acc: 0.137765)
# (Epoch 27 / 50), train acc: 0.700294, val_acc: 0.145353)
# (Iteration 111 / 200) loss:  1.794992
# (Epoch 28 / 50), train acc: 0.692000, val_acc: 0.139471)
# (Epoch 29 / 50), train acc: 0.701882, val_acc: 0.139471)
# (Epoch 30 / 50), train acc: 0.707353, val_acc: 0.145235)
# (Iteration 121 / 200) loss:  1.231272
# (Epoch 31 / 50), train acc: 0.712176, val_acc: 0.140588)
# (Epoch 32 / 50), train acc: 0.710471, val_acc: 0.139882)
# (Iteration 131 / 200) loss:  0.853470
# (Epoch 33 / 50), train acc: 0.711647, val_acc: 0.138941)
# (Epoch 34 / 50), train acc: 0.704529, val_acc: 0.140529)
# (Epoch 35 / 50), train acc: 0.705765, val_acc: 0.142471)
# (Iteration 141 / 200) loss:  0.816121
# (Epoch 36 / 50), train acc: 0.711529, val_acc: 0.142765)
# (Epoch 37 / 50), train acc: 0.705882, val_acc: 0.141529)
# (Iteration 151 / 200) loss:  0.677542
# (Epoch 38 / 50), train acc: 0.711882, val_acc: 0.137529)
# (Epoch 39 / 50), train acc: 0.709882, val_acc: 0.136588)
# (Epoch 40 / 50), train acc: 0.716118, val_acc: 0.139235)
# (Iteration 161 / 200) loss:  0.571129
# (Epoch 41 / 50), train acc: 0.705882, val_acc: 0.139353)
# (Epoch 42 / 50), train acc: 0.707529, val_acc: 0.139000)
# (Iteration 171 / 200) loss:  0.501678
# (Epoch 43 / 50), train acc: 0.716118, val_acc: 0.141529)
# (Epoch 44 / 50), train acc: 0.714294, val_acc: 0.142529)
# (Epoch 45 / 50), train acc: 0.706176, val_acc: 0.144412)
# (Iteration 181 / 200) loss:  0.525442
# (Epoch 46 / 50), train acc: 0.710176, val_acc: 0.141471)
# (Epoch 47 / 50), train acc: 0.705529, val_acc: 0.143765)
# (Iteration 191 / 200) loss:  0.430259
# (Epoch 48 / 50), train acc: 0.709765, val_acc: 0.140412)
# (Epoch 49 / 50), train acc: 0.710882, val_acc: 0.142706)
# (Epoch 50 / 50), train acc: 0.703588, val_acc: 0.142118)

# %% [markdown]
# ## Test-time sampling

# %%
for split in ['train','val']:
    minibatch = sample_coco_minibatch(small_data, split=split, batch_size=2)
    gt_captions, features, urls = minibatch
    gt_captions = decode_captions(gt_captions, data['idx_to_word'])
    
    sample_captions = small_rnn_model.sample(features)
    sample_captions = decode_captions(sample_captions, data['idx_to_word'])
#     print(gt_captions, len(gt_captions))
#     print(sample_captions, len(sample_captions))
    
    for gt_caption, sample_caption, url in zip(gt_captions, sample_captions, urls):
        plt.imshow(image_from_url(url))
        plt.title('%s\n%s\npredict:%s' % (split, gt_caption, sample_caption))
        plt.axis('off')
        plt.show()

# %% [markdown]
# ## train a best model

# %%
more_data = load_coco_data(max_train=20000)

best_rnn_model = CaptioningRNN(cell_type='rnn',
                                word_to_idx=data['word_to_idx'],
                                input_dim=data['train_features'].shape[1],
                                hidden_dim=512, 
                                wordvec_dim=256)

best_rnn_solver = CaptioningSolver(best_rnn_model,
                                    more_data,
                                    update_rule='Adam',
                                    num_epochs=4,
                                    batch_size=25,
                                    optim_param={
                                        'learning_rate':5e-3,
                                    },
                                    lr_decay=0.95,
                                    verbose=True,
                                    p_num=10
                                   )

best_rnn_solver.train()

plt.plot(best_rnn_solver.loss_history)
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.title('Training loss history')
plt.show()
# Out:
# (Iteration 1 /
# (Iteration 2601 / 3200) loss:  39.984537
# (Iteration 2611 / 3200) loss:  35.776640
# (Iteration 2621 / 3200) loss:  39.511266
# (Iteration 2631 / 3200) loss:  41.616405
# (Iteration 2641 / 3200) loss:  36.893625
# (Iteration 2651 / 3200) loss:  41.871816
# (Iteration 2661 / 3200) loss:  40.621643
# (Iteration 2671 / 3200) loss:  41.512822
# (Iteration 2681 / 3200) loss:  42.619186
# (Iteration 2691 / 3200) loss:  41.022150
# (Iteration 2701 / 3200) loss:  46.186289
# (Iteration 2711 / 3200) loss:  40.671568
# (Iteration 2721 / 3200) loss:  41.575113
# (Iteration 2731 / 3200) loss:  41.848393
# (Iteration 2741 / 3200) loss:  36.587544
# (Iteration 2751 / 3200) loss:  38.379287
# (Iteration 2761 / 3200) loss:  38.151133
# (Iteration 2771 / 3200) loss:  35.108588
# (Iteration 2781 / 3200) loss:  41.459826
# (Iteration 2791 / 3200) loss:  43.646385
# (Iteration 2801 / 3200) loss:  38.848186
# (Iteration 2811 / 3200) loss:  36.770271
# (Iteration 2821 / 3200) loss:  37.685090
# (Iteration 2831 / 3200) loss:  42.596475
# (Iteration 2841 / 3200) loss:  39.580176
# (Iteration 2851 / 3200) loss:  38.630602
# (Iteration 2861 / 3200) loss:  38.685328
# (Iteration 2871 / 3200) loss:  39.665731
# (Iteration 2881 / 3200) loss:  39.215681
# (Iteration 2891 / 3200) loss:  35.998769
# (Iteration 2901 / 3200) loss:  37.164486
# (Iteration 2911 / 3200) loss:  40.294100
# (Iteration 2921 / 3200) loss:  40.493437
# (Iteration 2931 / 3200) loss:  41.747097
# (Iteration 2941 / 3200) loss:  38.114982
# (Iteration 2951 / 3200) loss:  39.612225
# (Iteration 2961 / 3200) loss:  38.306764
# (Iteration 2971 / 3200) loss:  43.983870
# (Iteration 2981 / 3200) loss:  43.120121
# (Iteration 2991 / 3200) loss:  40.643400
# (Iteration 3001 / 3200) loss:  36.583722
# (Iteration 3011 / 3200) loss:  38.398563
# (Iteration 3021 / 3200) loss:  41.796643
# (Iteration 3031 / 3200) loss:  40.429766
# (Iteration 3041 / 3200) loss:  37.289759
# (Iteration 3051 / 3200) loss:  41.366046
# (Iteration 3061 / 3200) loss:  42.722754
# (Iteration 3071 / 3200) loss:  36.913799
# (Iteration 3081 / 3200) loss:  40.835956
# (Iteration 3091 / 3200) loss:  40.967282
# (Iteration 3101 / 3200) loss:  38.794561
# (Iteration 3111 / 3200) loss:  37.965758
# (Iteration 3121 / 3200) loss:  43.663116
# (Iteration 3131 / 3200) loss:  41.827570
# (Iteration 3141 / 3200) loss:  39.303107
# (Iteration 3151 / 3200) loss:  42.602738
# (Iteration 3161 / 3200) loss:  34.157205
# (Iteration 3171 / 3200) loss:  41.801125
# (Iteration 3181 / 3200) loss:  38.284942
# (Iteration 3191 / 3200) loss:  38.091236
# (Epoch 4 / 4), train acc: 0.163235, val_acc: 0.164765)

# %%
for split in ['train','val']:
    minibatch = sample_coco_minibatch(small_data, split=split, batch_size=2)
    gt_captions, features, urls = minibatch
    gt_captions = decode_captions(gt_captions, data['idx_to_word'])
    
    sample_captions = best_rnn_model.sample(features)
    sample_captions = decode_captions(sample_captions, data['idx_to_word'])
#     print(gt_captions, len(gt_captions))
#     print(sample_captions, len(sample_captions))
    
    for gt_caption, sample_caption, url in zip(gt_captions, sample_captions, urls):
        plt.imshow(image_from_url(url))
        plt.title('%s\n%s\npredict:%s' % (split, gt_caption, sample_caption))
        plt.axis('off')
        plt.show()
